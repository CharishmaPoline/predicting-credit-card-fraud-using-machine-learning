# %%
#importing Required documents
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
#this is my jupiter book running file
import os
print(os.getcwd())
# Out:
# C:\Users\chari\Documents

# %%
#Change the working directory(becuase my csv file is not in the jupiter book path)
import os
os.chdir(r"C:\Users\chari\OneDrive\Documents\Job related\coding")

# %%
                                              #DATA PREPROCESSING#
# 1.Import data set
import pandas as pd
credit_card = pd.read_csv("creditcard.csv")
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# 2.Exploratory Data Analysis
rows, columns = credit_card.shape
print(f"Number of Rows: {rows}")
print(f"Number of Columns: {columns}")
# Out:
# Number of Rows: 284807
# Number of Columns: 31

# %%
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card.duplicated().sum
# Out:
# <bound method Series.sum of 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool>

# %%
credit_card.duplicated().any()
# Out:
# True

# %%
credit_card.shape
# Out:
# (284807, 31)

# %%
#Remove duplication
credit_card_new = credit_card.drop_duplicates()
credit_card_new.shape
# Out:
# (283726, 31)

# %%
print(f"Duplicate Transaction:",284807 - 283726)
# Out:
# Duplicate Transaction: 1081

# %%
print(credit_card_new.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
credit_card_new['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
# Count of Legitimate (0) and Fraudulent (1) transactions
credit_card_new['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
legit = credit_card_new[credit_card_new['Class'] == 0]
print("Legitimate Transactions:")
print(legit.head())
# Out:
# Legitimate Transactions:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
fraud = credit_card_new[credit_card_new['Class'] == 1]
print("Fraudulent Transactions:")
print(fraud.head())
# Out:
# Fraudulent Transactions:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
print(f"Number of Legitimate Transactions: {len(legit)}")
print(f"Number of Fraudulent Transactions: {len(fraud)}")
# Out:
# Number of Legitimate Transactions: 283253
# Number of Fraudulent Transactions: 473

# %%
# Plotting the count of legitimate and fraudulent transactions with the correct column name
credit_card['Class'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Class'>

# %%
283253/283726
# Out:
# 0.9983328986416472

# %%
473/283726
# Out:
# 0.001667101358352777

# %%
# stataticas
credit_card_new.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
# Define X and Y with the correct column names
X = credit_card_new.drop('Class', axis=1)  # Remove the target variable 'Class'
Y = credit_card_new['Class']  # Use 'Class' as the dependent variable

# %%
###1. Understand the Problem:
Imbalanced Data: This occurs when one class (e.g., legitimate transactions) outnumbers the other (e.g., fraudulent transactions). This can lead to biased models that predict the majority class more frequently.

2. Resampling Techniques:
A. Oversampling the Minority Class:

SMOTE (Synthetic Minority Over-sampling Technique): Creates synthetic samples for the minority class by generating new examples based on existing data points.

Random Oversampling: Randomly duplicates examples from the minority class to balance the dataset.

B. Undersampling the Majority Class:

Random Undersampling: Removes random examples from the majority class to balance the dataset, but this can lead to the loss of useful data.

Tomek Links: Removes examples from the majority class that are very close to the minority class to clean up the data.

C. Hybrid Methods:

SMOTE + ENN (Edited Nearest Neighbors): Combines oversampling (SMOTE) with cleaning techniques (ENN) to reduce noise and balance the data.

3. Algorithm-Level Techniques:
Class Weighting: Many algorithms like logistic regression or random forests allow you to assign higher weights to the minority class, making the model pay more attention to it.

Cost-Sensitive Learning: Modify the learning algorithm so that it penalizes misclassifications of the minority class more heavily.

4. Use Appropriate Evaluation Metrics:
Accuracy is not reliable in imbalanced datasets because predicting the majority class all the time can still give high accuracy.

Precision, Recall, and F1-Score: Focus on how well the model performs on the minority class.

Confusion Matrix: Helps you understand false positives and false negatives.

ROC-AUC: Measures how well the model distinguishes between classes, which is especially important for imbalanced data.

5. Cross-Validation:
Use Stratified Cross-Validation, which ensures each fold of the data contains the same proportion of classes as the original dataset.

6. Try Specialized Models:
Some models like XGBoost and LightGBM have built-in support to handle imbalanced data.

Ensemble Methods like Balanced Random Forests or EasyEnsemble can be helpful for better classification of imbalanced classes.###

# %%
X.shape
# Out:
# (283726, 30)

# %%
Y.shape
# Out:
# (283726,)

# %%
#! pip install imblearn
from imblearn.over_sampling import SMOTE

# %%
from imblearn.over_sampling import SMOTE

# Assuming you have X (independent variables) and Y (target variable) already defined
smote = SMOTE(random_state=42)
X_smote, y_smote = smote.fit_resample(X, Y)

# %%
X_smote.shape
# Out:
# (566506, 30)

# %%
y_smote.value_counts()
# Out:
# Class
# 0    283253
# 1    283253
# Name: count, dtype: int64

# %%
from collections import Counter

# Check the class distribution in the original dataset (Y) and the resampled dataset (y_smote)
print('Original dataset shape:', Counter(Y))
print('Resampled dataset shape:', Counter(y_smote))
# Out:
# Original dataset shape: Counter({0: 283253, 1: 473})
# Resampled dataset shape: Counter({0: 283253, 1: 283253})

# %%
##Data Visualization
fraud_data = credit_card_new[credit_card_new['Class'] == 0]
legitimate_data = credit_card_new[credit_card_new['Class'] == 1]

# %%
fraud_data['Amount'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
legitimate_data['Amount'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
fraud_data['Amount'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
legitimate_data['Amount'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
###Correlation Matrix in imbalanced data
corr_imbalced = credit_card_new.select_dtypes(include=['float64', 'int64']).corr()
corr_imbalced
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# Time    1.000000  0.117927 -0.010556 -0.422054 -0.105845  0.173223 -0.063279
# V1      0.117927  1.000000  0.006875 -0.008112  0.002257 -0.007036  0.000413
# V2     -0.010556  0.006875  1.000000  0.005278 -0.001495  0.005210 -0.000594
# V3     -0.422054 -0.008112  0.005278  1.000000  0.002829 -0.006879 -0.001511
# V4     -0.105845  0.002257 -0.001495  0.002829  1.000000  0.001744 -0.000880
# V5      0.173223 -0.007036  0.005210 -0.006879  0.001744  1.000000 -0.000938
# V6     -0.063279  0.000413 -0.000594 -0.001511 -0.000880 -0.000938  1.000000
# V7      0.085335 -0.009173  0.007425 -0.011721  0.004657 -0.008709  0.000436
# V8     -0.038203 -0.001168  0.002899 -0.001815  0.000890  0.001430  0.003036
# V9     -0.007861  0.001828 -0.000274 -0.003579  0.002154 -0.001213 -0.000734
# V10     0.031068  0.000815  0.000620 -0.009632  0.002753 -0.006050 -0.002180
# ...

# %%
import matplotlib.pyplot as plt  # Importing for plotting
import seaborn as sns  # Importing seaborn for heatmap

# Correlation Matrix for Imbalanced Data
corr_imbalanced = credit_card.corr()  # Compute the correlation matrix

plt.figure(figsize=(8, 6))  # Set the figure size
sns.heatmap(corr_imbalanced, annot=False, cmap="plasma", linewidths=0.5)  # Plot the heatmap
plt.title("Correlation Matrix for Imbalanced Data")  # Set the title
plt.show()  # Display the plot

# %%
##corelation matrix in balanced data
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you've already resampled your dataset using SMOTE and have X_smote and y_smote

# Combine the resampled data into a single DataFrame
balanced_data = X_smote.copy()
balanced_data['class'] = y_smote

# Calculate the correlation matrix for the balanced dataset
corr_balanced = balanced_data.corr()

# Plot the correlation matrix
plt.figure(figsize=(8, 6))  # Set the figure size
sns.heatmap(corr_balanced, annot=False, cmap="plasma", linewidths=0.5)  # Plot the heatmap
plt.title("Correlation Matrix for Balanced Data")  # Set the title
plt.show()  # Display the plot

# %%
# Plotting class distribution before resampling
plt.figure(figsize=(6,4))
credit_card_new['Class'].value_counts().plot(kind='bar', color=['salmon', 'lightgreen'])
plt.title('Class Distribution (Before Resampling)')
plt.xlabel('Class (0 - Fraudulent, 1 - Legitimate)')
plt.ylabel('Count')
plt.xticks([0, 1], ['Fraudulent', 'Legitimate'], rotation=0)
plt.show()

# %%
# Plotting class distribution after resampling (SMOTE)
plt.figure(figsize=(6, 4))
pd.Series(y_smote).value_counts().plot(kind='bar', color=['salmon', 'lightgreen'])
plt.title('Class Distribution (After Resampling with SMOTE)')
plt.xlabel('Class (0 - Fraudulent, 1 - Legitimate)')
plt.ylabel('Count')
plt.xticks([0, 1], ['Fraudulent', 'Legitimate'], rotation=0)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.2, random_state=42)

# Print the shape of the splits to confirm
print(f"Training set features shape: {X_train.shape}")
print(f"Testing set features shape: {X_test.shape}")
print(f"Training set labels shape: {y_train.shape}")
print(f"Testing set labels shape: {y_test.shape}")
# Out:
# Training set features shape: (453204, 30)
# Testing set features shape: (113302, 30)
# Training set labels shape: (453204,)
# Testing set labels shape: (113302,)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train the Logistic Regression model with increased iterations
log_reg = LogisticRegression(random_state=42, max_iter=500)  # Increase iterations
log_reg.fit(X_train_scaled, y_train)

# Predict the labels on the test set
y_pred = log_reg.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Print the classification report for precision, recall, and f1-score
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion Matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 97.89%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     56463
#            1       0.99      0.97      0.98     56839
#
#     accuracy                           0.98    113302
#    macro avg       0.98      0.98      0.98    113302
# weighted avg       0.98      0.98      0.98    113302
#
#
# Confusion Matrix:
# [[55931   532]
#  [ 1858 54981]]

# %%
####1. Model Training:(i start by training our logistic regression model on the training dataset. In this step, the model learns the relationship between the independent variables (features) and the dependent variable (target).

                        Logistic regression is a linear model used for classification tasks, such as predicting whether a credit card transaction is fraudulent or not.

###2. Making Predictions:After the model is trained, you use the predict() function to generate predictions. You input the features from the test dataset, and the model will output predictions for each instance (row) in the test set.

                          This step essentially applies what the model has learned during training to new, unseen data.

3. Evaluation Metrics:
Once you have the predicted values, you evaluate how well your model performed using several metrics:

Accuracy: Measures the proportion of correct predictions (both true positives and true negatives) out of all predictions. It’s a simple metric but may not be sufficient for imbalanced datasets.

Precision: Shows how many of the predicted positive cases (e.g., fraud cases) were actually correct.

Recall: Shows how many of the actual positive cases were correctly identified by the model.

F1-Score: The harmonic mean of precision and recall, balancing both metrics.

Confusion Matrix: A matrix that shows the counts of true positives, false positives, true negatives, and false negatives. It gives a detailed breakdown of the model's performance across different categories.

4. Handling Convergence Warnings:
Logistic regression may raise a convergence warning if the model doesn't converge within the set number of iterations (max_iter). This can happen if the data is very complex or if scaling isn't applied.

If you encounter this, you may increase the number of iterations or standardize the features to help the model converge.

# %%
###Classification Report:
from sklearn.metrics import classification_report

# Assuming you have y_test as the true labels and y_pred as the predicted labels
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     56463
#            1       0.99      0.97      0.98     56839
#
#     accuracy                           0.98    113302
#    macro avg       0.98      0.98      0.98    113302
# weighted avg       0.98      0.98      0.98    113302

# %%
##Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have y_test as the true labels and y_pred as the predicted labels
cm = confusion_matrix(y_test, y_pred)

# Plotting the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Legitimate', 'Fraudulent'], yticklabels=['Legitimate', 'Fraudulent'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
pip install pandas scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Sample transaction data (customized input)
transaction_data = pd.DataFrame({
    'Time': [16],
    'V1': [1.322707269],
    'V2': [-0.174040833],
    'V3': [0.434555031],
    'V4': [0.576037652],
    'V5': [-0.36758046],
    'V6': [-0.831083411],
    'V7': [-0.264904961],
    'V8': [-0.220981943],
    'V9': [-1.071426418],
    'V10': [0.868585848],
    'V11': [-0.64150629],
    'V12': [-0.111315775],
    'V13': [0.36148541],
    'V14': [0.171945122],
    'V15': [0.782166532],
    'V16': [-1.355870873],
    'V17': [-0.216935153],
    'V18': [1.71765385],
    'V19': [-1.240621935],
    'V20': [-0.522950941],
    'V21': [0.80337573],
    'V22': [-0.672783422],
    'V23': [0.576654242],
    'V24': [-0.996401911],
    'V25': [0.36608725],
    'V26': [-0.274915004],
    'V27': [0.173053144],
    'V28': [-0.657312434],
    'Amount': [149.62]
})

# Predict using a trained model (example)
# prediction = model.predict(transaction_data)
# print("Prediction:", "Fraud" if prediction[0] == 1 else "Not Fraud")

# %%
transaction_data
# Out:
#    Time        V1        V2        V3        V4       V5        V6        V7  \
# 0    16  1.322707 -0.174041  0.434555  0.576038 -0.36758 -0.831083 -0.264905
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0 -0.220982 -1.071426  ... -0.522951  0.803376 -0.672783  0.576654 -0.996402
#
#         V25       V26       V27       V28  Amount
# 0  0.366087 -0.274915  0.173053 -0.657312  149.62
#
# [1 rows x 30 columns]

# %%
# Scale the custom transaction using the same scaler
transaction_scaled = scaler.transform(transaction_data)

# Make prediction
new_predictions = logistic_model.predict(transaction_scaled)

# Display result
print(f"\nTime: {transaction_data['Time'][0]}")
print("Predict:", "Fraudulent Transaction" if new_predictions[0] == 1 else "Genuine Transaction")
# Out:
# Time: 16
# Predict: Genuine Transaction

# %%
import numpy as np
import pandas as pd

# Define time range manually
min_time = 0
max_time = 172792  # Replace with realistic max if needed

# Generate 28 random transactions
num_transactions = 28
np.random.seed(42)

random_transactions = pd.DataFrame({
    'Time': np.random.randint(min_time, max_time + 1, size=num_transactions),
    'V1': np.random.normal(0, 1, size=num_transactions),
    'V2': np.random.normal(0, 1, size=num_transactions),
    'V3': np.random.normal(0, 1, size=num_transactions),
    'V4': np.random.normal(0, 1, size=num_transactions),
    'V5': np.random.normal(0, 1, size=num_transactions),
    'V6': np.random.normal(0, 1, size=num_transactions),
    'V7': np.random.normal(0, 1, size=num_transactions),
    'V8': np.random.normal(0, 1, size=num_transactions),
    'V9': np.random.normal(0, 1, size=num_transactions),
    'V10': np.random.normal(0, 1, size=num_transactions),
    'V11': np.random.normal(0, 1, size=num_transactions),
    'V12': np.random.normal(0, 1, size=num_transactions),
    'V13': np.random.normal(0, 1, size=num_transactions),
    'V14': np.random.normal(0, 1, size=num_transactions),
    'V15': np.random.normal(0, 1, size=num_transactions),
    'V16': np.random.normal(0, 1, size=num_transactions),
    'V17': np.random.normal(0, 1, size=num_transactions),
    'V18': np.random.normal(0, 1, size=num_transactions),
    'V19': np.random.normal(0, 1, size=num_transactions),
    'V20': np.random.normal(0, 1, size=num_transactions),
    'V21': np.random.normal(0, 1, size=num_transactions),
    'V22': np.random.normal(0, 1, size=num_transactions),
    'V23': np.random.normal(0, 1, size=num_transactions),
    'V24': np.random.normal(0, 1, size=num_transactions),
    'V25': np.random.normal(0, 1, size=num_transactions),
    'V26': np.random.normal(0, 1, size=num_transactions),
    'V27': np.random.normal(0, 1, size=num_transactions),
    'V28': np.random.normal(0, 1, size=num_transactions),
    'Amount': np.random.uniform(0, 500, size=num_transactions)
})

# Scale and predict
random_scaled = scaler.transform(random_transactions)
predictions = logistic_model.predict(random_scaled)

# Output results
for i in range(num_transactions):
    print(f"Transaction {i+1}: Time = {random_transactions['Time'][i]} | Predict: {'Fraudulent' if predictions[i] == 1 else 'Genuine'} Transaction")
# Out:
# Transaction 1: Time = 121958 | Predict: Genuine Transaction
# Transaction 2: Time = 146867 | Predict: Genuine Transaction
# Transaction 3: Time = 131932 | Predict: Genuine Transaction
# Transaction 4: Time = 103694 | Predict: Genuine Transaction
# Transaction 5: Time = 119879 | Predict: Genuine Transaction
# Transaction 6: Time = 110268 | Predict: Genuine Transaction
# Transaction 7: Time = 54886 | Predict: Genuine Transaction
# Transaction 8: Time = 137337 | Predict: Genuine Transaction
# Transaction 9: Time = 168266 | Predict: Genuine Transaction
# Transaction 10: Time = 87498 | Predict: Genuine Transaction
# Transaction 11: Time = 112727 | Predict: Genuine Transaction
# Transaction 12: Time = 126324 | Predict: Genuine Transaction
# Transaction 13: Time = 16023 | Predict: Genuine Transaction
# Transaction 14: Time = 41090 | Predict: Genuine Transaction
# Transaction 15: Time = 67221 | Predict: Genuine Transaction
# Transaction 16: Time = 64820 | Predict: Genuine Transaction
# ...

# %%
##ROC curve and calculate AUC
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# %%
# Get predicted probabilities (for the positive class)
y_probs = logistic_model.predict_proba(random_scaled)[:, 1]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# ----------------------
# STEP 1: Generate 28 random transactions
# ----------------------
num_transactions = 28
np.random.seed(42)

random_transactions = pd.DataFrame({
    'Time': np.random.randint(0, 172792, size=num_transactions),
    'V1': np.random.normal(0, 1, size=num_transactions),
    'V2': np.random.normal(0, 1, size=num_transactions),
    'V3': np.random.normal(0, 1, size=num_transactions),
    'V4': np.random.normal(0, 1, size=num_transactions),
    'V5': np.random.normal(0, 1, size=num_transactions),
    'V6': np.random.normal(0, 1, size=num_transactions),
    'V7': np.random.normal(0, 1, size=num_transactions),
    'V8': np.random.normal(0, 1, size=num_transactions),
    'V9': np.random.normal(0, 1, size=num_transactions),
    'V10': np.random.normal(0, 1, size=num_transactions),
    'V11': np.random.normal(0, 1, size=num_transactions),
    'V12': np.random.normal(0, 1, size=num_transactions),
    'V13': np.random.normal(0, 1, size=num_transactions),
    'V14': np.random.normal(0, 1, size=num_transactions),
    'V15': np.random.normal(0, 1, size=num_transactions),
    'V16': np.random.normal(0, 1, size=num_transactions),
    'V17': np.random.normal(0, 1, size=num_transactions),
    'V18': np.random.normal(0, 1, size=num_transactions),
    'V19': np.random.normal(0, 1, size=num_transactions),
    'V20': np.random.normal(0, 1, size=num_transactions),
    'V21': np.random.normal(0, 1, size=num_transactions),
    'V22': np.random.normal(0, 1, size=num_transactions),
    'V23': np.random.normal(0, 1, size=num_transactions),
    'V24': np.random.normal(0, 1, size=num_transactions),
    'V25': np.random.normal(0, 1, size=num_transactions),
    'V26': np.random.normal(0, 1, size=num_transactions),
    'V27': np.random.normal(0, 1, size=num_transactions),
    'V28': np.random.normal(0, 1, size=num_transactions),
    'Amount': np.random.uniform(0, 500, size=num_transactions)
})

# ----------------------
# STEP 2: Scale using your trained scaler
# ----------------------
random_scaled = scaler.transform(random_transactions)

# ----------------------
# STEP 3: Predict probabilities using your model
# ----------------------
y_probs = logistic_model.predict_proba(random_scaled)[:, 1]

# ----------------------
# STEP 4: Create dummy true labels for testing
# ----------------------
y_true = np.array([0]*14 + [1]*14)  # 14 genuine + 14 fraudulent for testing

# ----------------------
# STEP 5: ROC Curve and AUC
# ----------------------
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_true, y_probs)
auc_score = roc_auc_score(y_true, y_probs)

# ----------------------
# STEP 6: Plot
# ----------------------
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.grid(True)
plt.show()
